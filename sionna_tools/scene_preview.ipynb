# %%
import sys
root_path = ".."
sys.path.append(root_path)

from package.sionna_simulation import SionnaSimulation

config_path = "../config.yaml"
frame_id = 88838
is_show_paths = True
is_show_orientations = True

sionna_script = SionnaSimulation()
sionna_script.init(config_path)
sionna_script.sionna_scene_preview(frame_id, is_show_paths, is_show_orientations)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772784907.534288    1226 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772784907.553767    1226 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
